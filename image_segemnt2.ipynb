# %% [markdown]
# <a href="https://colab.research.google.com/github/vaneesa-writes/micro_project/blob/main/image_segemnt2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cd406804-8612-4d1d-9ed3-fad8d8a1ebb8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cd406804-8612-4d1d-9ed3-fad8d8a1ebb8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Case_1-01.tif to Case_1-01.tif

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# read original image
image = cv2.imread("/content/Case_1-01.tif")
plt.imshow(image)

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
clahe = cv2.createCLAHE(clipLimit = 2.0, tileGridSize=(8, 8))
claheNorm = clahe.apply(gray)
cv2.imwrite('claheNorm1.png', claheNorm)
# Out:
# True

# %%
image.size
# Out:
# 4177920

# %%
from keras.preprocessing.image import load_img

# %%
img = cv2.imread('/content/claheNorm1.png', 0)

# %%
img.shape
# Out:
# (1024, 1360)

# %%
mask = np.zeros((1024, 1360, 1), dtype=int)
mask.fill(255)

# %%
for i in range(1024):
  for j in range(1360):
    if(img[i][j]>=100):
      mask[i][j]=0

# %%
cv2.imwrite('mask100.png', mask)
# Out:
# True
